# %%
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_path = '/crnldata/cophy/TeamProjects/mohammad/ibl-oscillations/_analyses/_IBLworkflows/preprocessing/clean_data_with_significant_channels.csv'
path_fig = '/crnldata/cophy/TeamProjects/mohammad/ibl-oscillations/_analyses/_IBLworkflows/decoding/figures'
table = pd.read_csv(df_path)


for row in table.iterrows():
    row = row[1]
    pid = row['pid']
    print(f'pid = {pid}')
    for condition, signif_channel_col in {
    'Stim_NoStim': 'signif_channel_StimNoStim'}.items():
        signif_channels = row[signif_channel_col]
        if pd.isna(signif_channels) or not signif_channels:
            continue
        if isinstance(signif_channels, str):
            signif_channels = eval(signif_channels)
        for item in signif_channels:
            
            ch_name = item[0]
            acc = item[1]
            print(f'ch_name = {ch_name}, acc = {acc}')
# Out:
# pid = 3d3d5a5e-df26-43ee-80b6-2d72d85668a5
# ch_name = VISp6a_338, acc = 0.5944444444444444
# ch_name = VISp6a_346, acc = 0.5361111111111111
# ch_name = VISp6a_350, acc = 0.5958333333333333
# ch_name = VISp5_356, acc = 0.5416666666666666
# ch_name = VISp5_359, acc = 0.5375
# ch_name = VISp5_362, acc = 0.5583333333333333
# ch_name = VISp5_365, acc = 0.5402777777777777
# ch_name = VISp5_370, acc = 0.5458333333333333
# ch_name = VISp4_374, acc = 0.6222222222222222
# ch_name = VISp4_380, acc = 0.5694444444444444
# pid = 4b93a168-0f3b-4124-88fa-a57046ca70e1
# ch_name = VISp6a_324, acc = 0.5456790123456791
# ch_name = VISp6a_330, acc = 0.5567901234567901
# ch_name = VISp5_336, acc = 0.5320987654320988
# ch_name = VISp5_352, acc = 0.5518518518518518
# ch_name = VISp4_358, acc = 0.5308641975308642
# ch_name = VISp2/3_368, acc = 0.5444444444444444
# ch_name = VISp2/3_374, acc = 0.5518518518518518
# ch_name = VISp2/3_377, acc = 0.5382716049382716
# ...

# %%
df_path = '/crnldata/cophy/TeamProjects/mohammad/ibl-oscillations/_analyses/_IBLworkflows/preprocessing/clean_data_with_significant_channels.csv'
path_fig = '/crnldata/cophy/TeamProjects/mohammad/ibl-oscillations/_analyses/_IBLworkflows/decoding/figures'
table = pd.read_csv(df_path)


for row in table.iterrows():
    row = row[1]
    pid = row['pid']
    if pid == '92822789-608f-44a6-ad64-fe549402b2df0':
        
        print(f'pid = {pid}')
        for condition, signif_channel_col in {
        'Right_Left': 'signif_channel_RightLeft'}.items():
            signif_channels = row[signif_channel_col]
            if pd.isna(signif_channels) or not signif_channels:
                continue
            if isinstance(signif_channels, str):
                signif_channels = eval(signif_channels)
            for item in signif_channels:
                
                ch_name = item[0]
                acc = item[1]
                print(f'ch_name = {ch_name}, acc = {acc}')

# %% [markdown]
# [('VISp6a_306', 0.5850187265917604), ('VISp6a_313', 0.5179775280898876), ('VISp6a_317', 0.5243445692883895), ('VISp5_323', 0.5205992509363296), ('VISp5_325', 0.5235955056179775), ('VISp5_334', 0.5314606741573034), ('VISp5_335', 0.5318352059925093), ('VISp4_341', 0.5176029962546816), ('VISp4_343', 0.5310861423220974), ('VISp2/3_347', 0.5303370786516854), ('VISp2/3_348', 0.5168539325842697), ('VISp2/3_352', 0.5355805243445693), ('VISp2/3_353', 0.5385767790262173), ('VISp2/3_357', 0.5378277153558052), ('VISp1_366', 0.5288389513108614), ('VISp1_367', 0.5576779026217229), ('VISp1_368', 0.5235955056179775)]
